# %% [markdown]
# # 스케줄링 GA 실행 결과

# %% [markdown]
# ## 모듈 import

# %%
import os
import json
import time
import random
import simpy
import matplotlib.pyplot as plt
import pandas as pd
from dotenv import load_dotenv

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

from utils import DataLoader, EventLogger
from utils.visualizer import create_gantt_chart
from simulation import Scheduler
from algorithms.genetic.encoder import encode
from algorithms.genetic.decoder import decode
from algorithms.genetic.ga import GA

# %% [markdown]
# ## 환경 설정

# %%
load_dotenv(override=True)


BASE_DATA_PATH = os.environ['BASE_DATA_PATH']

PM_LEVELS      = json.loads(os.environ['PM_LEVELS'])
POP_SIZE       = int(os.environ['POP_SIZE'])
N_GENERATIONS  = int(os.environ['N_GENERATIONS'])
CROSSOVER_RATE = float(os.environ['CROSSOVER_RATE'])
MUT_JOB        = float(os.environ['MUT_JOB'])
MUT_MACHINE    = float(os.environ['MUT_MACHINE'])
MUT_PM         = float(os.environ['MUT_PM'])
TOURNAMENT_K   = int(os.environ['TOURNAMENT_K'])
N_ELITES       = int(os.environ['N_ELITES'])
ALPHA          = float(os.environ['ALPHA'])
STAGNATION_PATIENCE = int(os.environ['STAGNATION_PATIENCE'])
MUTATION_BOOST      = float(os.environ['MUTATION_BOOST'])
IMMIGRANT_RATIO     = float(os.environ['IMMIGRANT_RATIO'])
BOOST_DURATION      = int(os.environ['BOOST_DURATION'])
BOOST_COOLDOWN      = int(os.environ['BOOST_COOLDOWN'])

# SEED: .env의 값이 있으면 고정, 비어있으면 랜덤
_seed_env = os.environ['SEED']
SEED = int(_seed_env) if _seed_env else random.randint(0, 10**6)

# 사용된 환경 변수 출력
print(f'BASE_DATA_PATH = {BASE_DATA_PATH}')
print(f'PM_LEVELS      = {PM_LEVELS}')
print(f'POP_SIZE       = {POP_SIZE}')
print(f'N_GENERATIONS  = {N_GENERATIONS}')
print(f'CROSSOVER_RATE = {CROSSOVER_RATE}')
print(f'MUT_JOB        = {MUT_JOB}')
print(f'MUT_MACHINE    = {MUT_MACHINE}')
print(f'MUT_PM         = {MUT_PM}')
print(f'TOURNAMENT_K   = {TOURNAMENT_K}')
print(f'N_ELITES       = {N_ELITES}')
print(f'ALPHA          = {ALPHA}')
print(f'STAGNATION_PATIENCE = {STAGNATION_PATIENCE}')
print(f'MUTATION_BOOST      = {MUTATION_BOOST}')
print(f'IMMIGRANT_RATIO     = {IMMIGRANT_RATIO}')
print(f'BOOST_DURATION      = {BOOST_DURATION}')
print(f'BOOST_COOLDOWN      = {BOOST_COOLDOWN}')
print(f'SEED           = {SEED}')
# Out:
# BASE_DATA_PATH = data/large_data
# PM_LEVELS      = [0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.2]
# POP_SIZE       = 100
# N_GENERATIONS  = 200
# CROSSOVER_RATE = 0.8
# MUT_JOB        = 0.01
# MUT_MACHINE    = 0.0005
# MUT_PM         = 0.005
# TOURNAMENT_K   = 3
# N_ELITES       = 1
# ALPHA          = 0.25
# STAGNATION_PATIENCE = 10
# MUTATION_BOOST      = 8.0
# IMMIGRANT_RATIO     = 0.2
# BOOST_DURATION      = 5
# BOOST_COOLDOWN      = 10
# SEED           = 500

# %% [markdown]
# ## 데이터 로드

# %%
data = DataLoader(BASE_DATA_PATH).load_all_data()

print('데이터 개요')
print(f'Jobs:        {len(data["jobs"])}개')
print(f'Operations:  {len(data["operations"])}개')
print(f'Machines:    {len(data["machines"])}개')
# Out:
# 데이터 개요
# Jobs:        60개
# Operations:  840개
# Machines:    60개

# %% [markdown]
# ## 인코딩

# %%
encoded = encode(data, pm_levels=PM_LEVELS)

print(f'job_index_table 길이:       {len(encoded.job_index_table)}')
print(f'machine_index_table 길이:   {len(encoded.machine_index_table)}')
print(f'operation_index_table 길이: {len(encoded.operation_index_table)}')
print(f'pm_levels:                  {encoded.pm_levels}')
# Out:
# job_index_table 길이:       60
# machine_index_table 길이:   60
# operation_index_table 길이: 840
# pm_levels:                  [0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.2]

# %% [markdown]
# ## GA 실행

# %%
ga = GA(
    encoded=encoded,
    data=data,
    pop_size=POP_SIZE,
    n_generations=N_GENERATIONS,
    crossover_rate=CROSSOVER_RATE,
    mut_job=MUT_JOB,
    mut_machine=MUT_MACHINE,
    mut_pm=MUT_PM,
    tournament_k=TOURNAMENT_K,
    n_elites=N_ELITES,
    alpha=ALPHA,
    seed=SEED,
    stagnation_patience=STAGNATION_PATIENCE,
    mutation_boost=MUTATION_BOOST,
    immigrant_ratio=IMMIGRANT_RATIO,
    boost_duration=BOOST_DURATION,
    boost_cooldown=BOOST_COOLDOWN,
    verbose=True,     
    verbose_interval=1,
)

t0 = time.time()
best, history = ga.run()
elapsed = time.time() - t0

print(f'\nGA 실행 시간: {elapsed:.2f}초 ({elapsed/60:.2f}분)')
# Out:
# GA:   0%|          | 0/200 [00:00<?, ?gen/s]
# [Gen   0] best_fitness=325.46  makespan=234.87  qtime=362.35  avg=434.00
# [Gen   1] best_fitness=323.86  makespan=251.29  qtime=290.28  avg=414.58
# [Gen   2] best_fitness=323.86  makespan=251.29  qtime=290.28  avg=406.52
# [Gen   3] best_fitness=315.23  makespan=253.75  qtime=245.92  avg=399.09
# [Gen   4] best_fitness=315.23  makespan=253.75  qtime=245.92  avg=399.82
# [Gen   5] best_fitness=313.32  makespan=237.03  qtime=305.15  avg=396.39
# [Gen   6] best_fitness=306.28  makespan=252.78  qtime=214.02  avg=398.17
# [Gen   7] best_fitness=306.28  makespan=252.78  qtime=214.02  avg=400.39
# [Gen   8] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=391.37
# [Gen   9] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=387.04
# [Gen  10] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=388.05
# [Gen  11] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=381.89
# [Gen  12] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=376.19
# [Gen  13] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=366.50
# [Gen  14] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=372.42
# [Gen  15] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=366.28
# [Gen  16] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=370.29
# [Gen  17] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=370.48
# [Gen  18] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=368.19
# [Gen  19] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=369.95  [BOOST]
# [Gen  20] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=367.94  [BOOST]
# [Gen  21] best_fitness=292.81  makespan=244.18  qtime=194.50  avg=370.51  [BOOST]
# [Gen  22] best_fitness=292.44  makespan=241.63  qtime=203.21  avg=370.24  [BOOST]
# [Gen  23] best_fitness=292.44  makespan=241.63  qtime=203.21  avg=365.61
# [Gen  24] best_fitness=292.44  makespan=241.63  qtime=203.21  avg=362.74
# [Gen  25] best_fitness=292.44  makespan=241.63  qtime=203.21  avg=360.41
# [Gen  26] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=367.85
# [Gen  27] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=363.29
# [Gen  28] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=358.60
# [Gen  29] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=351.76
# [Gen  30] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=351.74
# [Gen  31] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=353.77
# [Gen  32] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=352.52
# [Gen  33] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=349.95
# [Gen  34] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=345.08
# [Gen  35] best_fitness=285.88  makespan=241.05  qtime=179.31  avg=348.00
# [Gen  36] best_fitness=282.22  makespan=248.20  qtime=136.09  avg=341.22
# [Gen  37] best_fitness=282.22  makespan=248.20  qtime=136.09  avg=337.67
# [Gen  38] best_fitness=282.22  makespan=248.20  qtime=136.09  avg=334.07
# [Gen  39] best_fitness=282.22  makespan=248.20  qtime=136.09  avg=332.76
# [Gen  40] best_fitness=282.22  makespan=248.20  qtime=136.09  avg=337.58
# [Gen  41] best_fitness=282.22  makespan=248.20  qtime=136.09  avg=331.00
# [Gen  42] best_fitness=275.60  makespan=244.59  qtime=124.02  avg=327.64
# [Gen  43] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=323.10
# [Gen  44] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=326.73
# [Gen  45] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=320.29
# [Gen  46] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=325.27
# [Gen  47] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=317.49
# [Gen  48] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=316.54
# [Gen  49] best_fitness=269.06  makespan=228.08  qtime=163.96  avg=315.68
# [Gen  50] best_fitness=268.01  makespan=237.01  qtime=124.00  avg=313.02
# [Gen  51] best_fitness=261.72  makespan=237.83  qtime=95.56  avg=307.92
# [Gen  52] best_fitness=261.72  makespan=237.83  qtime=95.56  avg=310.71
# [Gen  53] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=306.05
# [Gen  54] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=301.66
# [Gen  55] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=305.51
# [Gen  56] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=311.69
# [Gen  57] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=306.05
# [Gen  58] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=304.35
# [Gen  59] best_fitness=259.58  makespan=232.81  qtime=107.05  avg=302.63
# [Gen  60] best_fitness=255.36  makespan=238.24  qtime=68.49  avg=305.45
# [Gen  61] best_fitness=255.36  makespan=238.24  qtime=68.49  avg=302.22
# [Gen  62] best_fitness=253.54  makespan=235.48  qtime=72.27  avg=302.10
# [Gen  63] best_fitness=252.55  makespan=233.01  qtime=78.18  avg=305.76
# [Gen  64] best_fitness=252.55  makespan=233.01  qtime=78.18  avg=304.15
# [Gen  65] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=302.82
# [Gen  66] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=299.32
# [Gen  67] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=301.21
# [Gen  68] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=302.30
# [Gen  69] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=300.81
# [Gen  70] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=298.19
# [Gen  71] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=292.59
# [Gen  72] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=300.67
# [Gen  73] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=297.68
# [Gen  74] best_fitness=252.45  makespan=232.87  qtime=78.31  avg=299.74
# [Gen  75] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=296.24
# [Gen  76] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=296.21
# [Gen  77] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=296.07
# [Gen  78] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=293.29
# [Gen  79] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=288.81
# [Gen  80] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=285.76
# [Gen  81] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=287.51
# [Gen  82] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=289.23
# [Gen  83] best_fitness=245.92  makespan=228.25  qtime=70.67  avg=285.48
# [Gen  84] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=283.76
# [Gen  85] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=285.19
# [Gen  86] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=281.62
# [Gen  87] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=281.03
# [Gen  88] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=281.47
# [Gen  89] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=279.04
# [Gen  90] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=280.93
# [Gen  91] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=279.24
# [Gen  92] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=282.75
# [Gen  93] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=279.71
# [Gen  94] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=278.13
# [Gen  95] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=297.52  [BOOST]
# [Gen  96] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=302.19  [BOOST]
# [Gen  97] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=307.41  [BOOST]
# [Gen  98] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=308.18  [BOOST]
# [Gen  99] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=306.77  [BOOST]
# [Gen 100] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=301.66
# [Gen 101] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=301.91
# [Gen 102] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=300.50
# [Gen 103] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=294.85
# [Gen 104] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=292.24
# [Gen 105] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=296.31
# [Gen 106] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=290.86
# [Gen 107] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=292.36
# [Gen 108] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=289.57
# [Gen 109] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=287.34
# [Gen 110] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=298.98  [BOOST]
# [Gen 111] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=304.62  [BOOST]
# [Gen 112] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=307.98  [BOOST]
# [Gen 113] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=311.17  [BOOST]
# [Gen 114] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=314.28  [BOOST]
# [Gen 115] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=305.69
# [Gen 116] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=308.53
# [Gen 117] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=305.69
# [Gen 118] best_fitness=242.79  makespan=226.22  qtime=66.24  avg=298.93
# [Gen 119] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=294.75
# [Gen 120] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=296.96
# [Gen 121] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=290.82
# [Gen 122] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=293.71
# [Gen 123] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=290.93
# [Gen 124] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=286.27
# [Gen 125] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=288.45
# [Gen 126] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=286.90
# [Gen 127] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=288.23
# [Gen 128] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=284.85
# [Gen 129] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=280.71
# [Gen 130] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=298.56  [BOOST]
# [Gen 131] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=308.79  [BOOST]
# [Gen 132] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=311.28  [BOOST]
# [Gen 133] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=311.50  [BOOST]
# [Gen 134] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=318.85  [BOOST]
# [Gen 135] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=307.86
# [Gen 136] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=306.97
# [Gen 137] best_fitness=242.65  makespan=226.09  qtime=66.24  avg=296.56
# [Gen 138] best_fitness=241.19  makespan=226.24  qtime=59.80  avg=293.48
# [Gen 139] best_fitness=241.19  makespan=226.24  qtime=59.80  avg=288.06
# [Gen 140] best_fitness=241.19  makespan=226.24  qtime=59.80  avg=280.41
# [Gen 141] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=275.58
# [Gen 142] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=271.02
# [Gen 143] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=267.96
# [Gen 144] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=270.44
# [Gen 145] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=266.13
# [Gen 146] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=266.64
# [Gen 147] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=265.96
# [Gen 148] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=267.70
# [Gen 149] best_fitness=237.13  makespan=224.74  qtime=49.58  avg=264.64
# [Gen 150] best_fitness=235.52  makespan=221.34  qtime=56.73  avg=264.33
# [Gen 151] best_fitness=235.52  makespan=221.34  qtime=56.73  avg=263.63
# [Gen 152] best_fitness=235.52  makespan=221.34  qtime=56.73  avg=265.12
# [Gen 153] best_fitness=235.52  makespan=221.34  qtime=56.73  avg=263.14
# [Gen 154] best_fitness=235.52  makespan=221.34  qtime=56.73  avg=260.69
# [Gen 155] best_fitness=235.52  makespan=221.34  qtime=56.73  avg=264.92
# [Gen 156] best_fitness=234.54  makespan=222.57  qtime=47.88  avg=264.24
# [Gen 157] best_fitness=233.89  makespan=221.20  qtime=50.77  avg=262.69
# [Gen 158] best_fitness=233.37  makespan=221.50  qtime=47.47  avg=264.35
# [Gen 159] best_fitness=231.25  makespan=220.20  qtime=44.20  avg=263.34
# [Gen 160] best_fitness=231.25  makespan=220.20  qtime=44.20  avg=264.03
# [Gen 161] best_fitness=231.25  makespan=220.20  qtime=44.20  avg=261.97
# [Gen 162] best_fitness=231.25  makespan=220.20  qtime=44.20  avg=262.76
# [Gen 163] best_fitness=229.47  makespan=217.58  qtime=47.56  avg=257.71
# [Gen 164] best_fitness=229.47  makespan=217.58  qtime=47.56  avg=261.83
# [Gen 165] best_fitness=229.47  makespan=217.58  qtime=47.56  avg=256.60
# [Gen 166] best_fitness=229.47  makespan=217.58  qtime=47.56  avg=258.59
# [Gen 167] best_fitness=229.47  makespan=217.58  qtime=47.56  avg=256.42
# [Gen 168] best_fitness=229.47  makespan=217.58  qtime=47.56  avg=255.18
# [Gen 169] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=257.61
# [Gen 170] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=258.86
# [Gen 171] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=256.29
# [Gen 172] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=255.27
# [Gen 173] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=257.23
# [Gen 174] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=255.18
# [Gen 175] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=258.68
# [Gen 176] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=256.85
# [Gen 177] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=261.04
# [Gen 178] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=261.23
# [Gen 179] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=257.67
# [Gen 180] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=292.09  [BOOST]
# [Gen 181] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=295.58  [BOOST]
# [Gen 182] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=301.47  [BOOST]
# [Gen 183] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=306.30  [BOOST]
# [Gen 184] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=306.77  [BOOST]
# [Gen 185] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=300.26
# [Gen 186] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=299.09
# [Gen 187] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=299.44
# [Gen 188] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=295.43
# [Gen 189] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=291.52
# [Gen 190] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=290.13
# [Gen 191] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=285.06
# [Gen 192] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=282.89
# [Gen 193] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=280.65
# [Gen 194] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=275.32
# [Gen 195] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=292.39  [BOOST]
# [Gen 196] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=301.11  [BOOST]
# [Gen 197] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=301.97  [BOOST]
# [Gen 198] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=306.79  [BOOST]
# [Gen 199] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=313.54  [BOOST]
# [Gen 200] best_fitness=227.49  makespan=218.52  qtime=35.88  avg=305.70
#
# GA 실행 시간: 1843.02초 (30.72분)

# %% [markdown]
# ## 수렴 곡선
#
# 세대별 best/avg fitness 추이 + best의 두 지표(makespan, qtime) 변화.

# %%
df_history = pd.DataFrame(history)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# (1) Fitness 수렴 곡선
axes[0].plot(df_history['gen'], df_history['best_fitness'], label='best', color='C0', linewidth=2)
axes[0].plot(df_history['gen'], df_history['avg_fitness'], label='avg', color='C1', alpha=0.6)
axes[0].set_xlabel('Generation')
axes[0].set_ylabel('Fitness (lower is better)')
axes[0].set_title('GA 수렴 곡선')
axes[0].legend()
axes[0].grid(alpha=0.3)

# (2) Best chromosome 두 지표 변화
ax2 = axes[1]
l1 = ax2.plot(df_history['gen'], df_history['best_makespan'], label='makespan', color='C2')
ax2.set_xlabel('Generation')
ax2.set_ylabel('makespan', color='C2')
ax2.tick_params(axis='y', labelcolor='C2')

ax2_t = ax2.twinx()
l2 = ax2_t.plot(df_history['gen'], df_history['best_qtime'], label='qtime', color='C3')
ax2_t.set_ylabel('qtime_violation', color='C3')
ax2_t.tick_params(axis='y', labelcolor='C3')

ax2.set_title('best chromosome 두 지표 변화')
ax2.grid(alpha=0.3)

lines = l1 + l2
ax2.legend(lines, [l.get_label() for l in lines], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 최종 best chromosome 정보

# %%
sim_input_best = decode(best, encoded)

print('─── best chromosome fitness ───')
print(f'  makespan: {best.fitness[0]:.2f}')
print(f'  qtime:    {best.fitness[1]:.2f}')
print()
print('─── 디코딩 결과 (시뮬 실제 입력) ───')
print(f'  job 투입 순서: {sim_input_best.job_priority}')
print()
print(f'  pm_thresholds: {sim_input_best.pm_thresholds}')
print()
print('  op별 머신 할당 (앞 10개):')
for op, m in list(sim_input_best.op_machine.items())[:10]:
    print(f'    {op} → {m}')
# Out:
# ─── best chromosome fitness ───
#   makespan: 218.52
#   qtime:    35.88
#
# ─── 디코딩 결과 (시뮬 실제 입력) ───
#   job 투입 순서: ['J30', 'J13', 'J27', 'J43', 'J8', 'J12', 'J14', 'J38', 'J54', 'J36', 'J50', 'J9', 'J2', 'J19', 'J15', 'J48', 'J20', 'J29', 'J39', 'J41', 'J34', 'J4', 'J56', 'J31', 'J35', 'J52', 'J11', 'J24', 'J1', 'J51', 'J42', 'J25', 'J57', 'J58', 'J49', 'J17', 'J3', 'J16', 'J37', 'J23', 'J46', 'J33', 'J55', 'J7', 'J53', 'J28', 'J21', 'J10', 'J60', 'J47', 'J44', 'J6', 'J26', 'J5', 'J32', 'J59', 'J40', 'J22', 'J18', 'J45']
#
#   pm_thresholds: {'M1': 0.03, 'M2': 0.03, 'M3': 0.09, 'M4': 0.1, 'M5': 0.01, 'M6': 0.05, 'M7': 0.09, 'M8': 0.05, 'M9': 0.01, 'M10': 0.05, 'M11': 0.1, 'M12': 0.2, 'M13': 0.01, 'M14': 0.01, 'M15': 0.05, 'M16': 0.07, 'M17': 0.07, 'M18': 0.01, 'M19': 0.01, 'M20': 0.05, 'M21': 0.09, 'M22': 0.05, 'M23': 0.01, 'M24': 0.2, 'M25': 0.2, 'M26': 0.07, 'M27': 0.03, 'M28': 0.05, 'M29': 0.01, 'M30': 0.07, 'M31': 0.05, 'M32': 0.1, 'M33': 0.1, 'M34': 0.07, 'M35': 0.03, 'M36': 0.05, 'M37': 0.09, 'M38': 0.03, 'M39': 0.07, 'M40': 0.1, 'M41': 0.09, 'M42': 0.01, 'M43': 0.2, 'M44': 0.07, 'M45': 0.07, 'M46': 0.07, 'M47': 0.07, 'M48': 0.1, 'M49': 0.05, 'M50': 0.2, 'M51': 0.2, 'M52': 0.09, 'M53': 0.1, 'M54': 0.2, 'M55': 0.07, 'M56': 0.03, 'M57': 0.1, 'M58': 0.03, 'M59': 0.09, 'M60': 0.03}
#
#   op별 머신 할당 (앞 10개):
#     J1_O1 → M43
#     J1_O2 → M17
#     J1_O3 → M50
#     J1_O4 → M24
#     J1_O5 → M58
#     J1_O6 → M19
#     J1_O7 → M37
#     J1_O8 → M12
#     J1_O9 → M51
#     J1_O10 → M26

# %% [markdown]
# ## Best chromosome 시뮬레이션 + 간트 차트
#
# GA가 찾아낸 best chromosome으로 시뮬레이션을 한 번 더 돌려 간트 차트 시각화.

# %%
# best chromosome으로 시뮬레이션 재실행 (시드 고정 → fitness와 동일 결과)
random.seed(ga.evaluator.seed)

env = simpy.Environment()
event_logger = EventLogger(env)
scheduler = Scheduler(
    env=env,
    data=data,
    event_logger=event_logger,
    pm_hazard_threshold=0.0,
    job_priority=sim_input_best.job_priority,
    op_machine=sim_input_best.op_machine,
    pm_thresholds=sim_input_best.pm_thresholds,
)
env.run(until=scheduler.job_chk_process)

fig = create_gantt_chart(
    logs=event_logger.logs,
    max_time=env.now,
    title=f'GA Best Chromosome 간트 차트 (Simulation Time: {round(env.now / 60, 3)} h)'
)
fig.show()

# %% [markdown]
# ## 초기 vs 최종 비교

# %%
init = history[0]
final = history[-1]

print('─── 초기 (gen 0, 무작위) ───')
print(f"  best fitness: {init['best_fitness']:.2f}")
print(f"    makespan:   {init['best_makespan']:.2f}")
print(f"    qtime:      {init['best_qtime']:.2f}")
print(f"  avg  fitness: {init['avg_fitness']:.2f}")
print()
print('─── 최종 (GA 진화 후) ───')
print(f"  best fitness: {final['best_fitness']:.2f}")
print(f"    makespan:   {final['best_makespan']:.2f}")
print(f"    qtime:      {final['best_qtime']:.2f}")
print(f"  avg  fitness: {final['avg_fitness']:.2f}")
print()

def pct_change(initial, final_val):
    """초기값이 0이면 절대 변화량 표시, 아니면 변화율(%) 표시."""
    if initial == 0:
        return f'{initial:.2f} → {final_val:.2f} (초기값 0이라 변화율 미정의)'
    return f'{(final_val - initial) / initial * 100:+.1f}%'

print(f'best fitness 개선율: {pct_change(init["best_fitness"], final["best_fitness"])}')
print(f'makespan 변화율:     {pct_change(init["best_makespan"], final["best_makespan"])}')
print(f'qtime 변화율:        {pct_change(init["best_qtime"], final["best_qtime"])}')
# Out:
# ─── 초기 (gen 0, 무작위) ───
#   best fitness: 325.46
#     makespan:   234.87
#     qtime:      362.35
#   avg  fitness: 434.00
#
# ─── 최종 (GA 진화 후) ───
#   best fitness: 227.49
#     makespan:   218.52
#     qtime:      35.88
#   avg  fitness: 305.70
#
# best fitness 개선율: -30.1%
# makespan 변화율:     -7.0%
# qtime 변화율:        -90.1%

# %% [markdown]
# ## 결과 저장
#
# 세대별 history는 CSV로, best chromosome 간트 차트는 HTML로 같은 폴더에 저장. 번호는 자동 증가.

# %%
SAVE_DIR = 'ga결과/'   # 결과 저장 폴더
os.makedirs(SAVE_DIR, exist_ok=True)


def next_filepath(prefix: str, suffix: str) -> str:
    """SAVE_DIR 안에서 {prefix}NNN{suffix} 패턴의 가장 큰 번호 + 1로 새 경로 반환."""
    existing_nums = [
        int(f[len(prefix):-len(suffix)])
        for f in os.listdir(SAVE_DIR)
        if f.startswith(prefix) and f.endswith(suffix)
        and f[len(prefix):-len(suffix)].isdigit()
    ]
    next_num = max(existing_nums, default=0) + 1
    return os.path.join(SAVE_DIR, f'{prefix}{next_num:03d}{suffix}')


# ─── CSV 저장 (세대별 history + GA 파라미터는 첫 행에만) ───
params = {
    'pm_levels':           str(PM_LEVELS),
    'pop_size':            POP_SIZE,
    'n_generations':       N_GENERATIONS,
    'crossover_rate':      CROSSOVER_RATE,
    'mut_job':             MUT_JOB,
    'mut_machine':         MUT_MACHINE,
    'mut_pm':              MUT_PM,
    'tournament_k':        TOURNAMENT_K,
    'n_elites':            N_ELITES,
    'alpha':               ALPHA,
    'stagnation_patience': STAGNATION_PATIENCE,
    'mutation_boost':      MUTATION_BOOST,
    'immigrant_ratio':     IMMIGRANT_RATIO,
    'boost_duration':      BOOST_DURATION,
    'boost_cooldown':      BOOST_COOLDOWN,
    'seed':                SEED,
}
df_out = df_history.copy()
for k, v in params.items():
    df_out[k] = ''
    df_out.at[0, k] = v

csv_path = next_filepath('result_ga_history_', '.csv')
df_out.to_csv(csv_path, index=False, encoding='utf-8-sig')
print(f'saved: {csv_path}')

# ─── HTML 저장 (best 간트 차트) ───
html_path = next_filepath('result_ga_gantt_', '.html')
fig.write_html(html_path)
print(f'saved: {html_path}')
# Out:
# saved: ga결과/result_ga_history_005.csv
# saved: ga결과/result_ga_gantt_005.html
