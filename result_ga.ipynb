# %% [markdown]
# # 스케줄링 GA 실행 결과

# %% [markdown]
# ## 모듈 import

# %%
import os
import json
import time
import random
import simpy
import matplotlib.pyplot as plt
import pandas as pd
from dotenv import load_dotenv

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

from utils import DataLoader, EventLogger
from utils.visualizer import create_gantt_chart
from simulation import Scheduler
from algorithms.genetic.encoder import encode
from algorithms.genetic.decoder import decode
from algorithms.genetic.ga import GA

# %% [markdown]
# ## 환경 설정

# %%
load_dotenv(override=True)


BASE_DATA_PATH = os.environ['BASE_DATA_PATH']

PM_LEVELS      = json.loads(os.environ['PM_LEVELS'])
POP_SIZE       = int(os.environ['POP_SIZE'])
N_GENERATIONS  = int(os.environ['N_GENERATIONS'])
CROSSOVER_RATE = float(os.environ['CROSSOVER_RATE'])
MUT_JOB        = float(os.environ['MUT_JOB'])
MUT_MACHINE    = float(os.environ['MUT_MACHINE'])
MUT_PM         = float(os.environ['MUT_PM'])
TOURNAMENT_K   = int(os.environ['TOURNAMENT_K'])
N_ELITES       = int(os.environ['N_ELITES'])
ALPHA          = float(os.environ['ALPHA'])
STAGNATION_PATIENCE = int(os.environ['STAGNATION_PATIENCE'])
MUTATION_BOOST      = float(os.environ['MUTATION_BOOST'])
IMMIGRANT_RATIO     = float(os.environ['IMMIGRANT_RATIO'])
BOOST_DURATION      = int(os.environ['BOOST_DURATION'])
BOOST_COOLDOWN      = int(os.environ['BOOST_COOLDOWN'])

# SEED: .env의 값이 있으면 고정, 비어있으면 랜덤
_seed_env = os.environ['SEED']
SEED = int(_seed_env) if _seed_env else random.randint(0, 10**6)

# 사용된 환경 변수 출력
print(f'BASE_DATA_PATH = {BASE_DATA_PATH}')
print(f'PM_LEVELS      = {PM_LEVELS}')
print(f'POP_SIZE       = {POP_SIZE}')
print(f'N_GENERATIONS  = {N_GENERATIONS}')
print(f'CROSSOVER_RATE = {CROSSOVER_RATE}')
print(f'MUT_JOB        = {MUT_JOB}')
print(f'MUT_MACHINE    = {MUT_MACHINE}')
print(f'MUT_PM         = {MUT_PM}')
print(f'TOURNAMENT_K   = {TOURNAMENT_K}')
print(f'N_ELITES       = {N_ELITES}')
print(f'ALPHA          = {ALPHA}')
print(f'STAGNATION_PATIENCE = {STAGNATION_PATIENCE}')
print(f'MUTATION_BOOST      = {MUTATION_BOOST}')
print(f'IMMIGRANT_RATIO     = {IMMIGRANT_RATIO}')
print(f'BOOST_DURATION      = {BOOST_DURATION}')
print(f'BOOST_COOLDOWN      = {BOOST_COOLDOWN}')
print(f'SEED           = {SEED}')
# Out:
# BASE_DATA_PATH = data/large_data
# PM_LEVELS      = [0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.2]
# POP_SIZE       = 100
# N_GENERATIONS  = 400
# CROSSOVER_RATE = 0.8
# MUT_JOB        = 0.01
# MUT_MACHINE    = 0.0005
# MUT_PM         = 0.005
# TOURNAMENT_K   = 3
# N_ELITES       = 1
# ALPHA          = 0.25
# STAGNATION_PATIENCE = 400
# MUTATION_BOOST      = 30.0
# IMMIGRANT_RATIO     = 0.5
# BOOST_DURATION      = 12
# BOOST_COOLDOWN      = 20
# SEED           = 500

# %% [markdown]
# ## 데이터 로드

# %%
data = DataLoader(BASE_DATA_PATH).load_all_data()

print('데이터 개요')
print(f'Jobs:        {len(data["jobs"])}개')
print(f'Operations:  {len(data["operations"])}개')
print(f'Machines:    {len(data["machines"])}개')
# Out:
# 데이터 개요
# Jobs:        60개
# Operations:  840개
# Machines:    60개

# %% [markdown]
# ## 인코딩

# %%
encoded = encode(data, pm_levels=PM_LEVELS)

print(f'job_index_table 길이:       {len(encoded.job_index_table)}')
print(f'machine_index_table 길이:   {len(encoded.machine_index_table)}')
print(f'operation_index_table 길이: {len(encoded.operation_index_table)}')
print(f'pm_levels:                  {encoded.pm_levels}')
# Out:
# job_index_table 길이:       60
# machine_index_table 길이:   60
# operation_index_table 길이: 840
# pm_levels:                  [0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.2]

# %% [markdown]
# ## GA 실행

# %%
ga = GA(
    encoded=encoded,
    data=data,
    pop_size=POP_SIZE,
    n_generations=N_GENERATIONS,
    crossover_rate=CROSSOVER_RATE,
    mut_job=MUT_JOB,
    mut_machine=MUT_MACHINE,
    mut_pm=MUT_PM,
    tournament_k=TOURNAMENT_K,
    n_elites=N_ELITES,
    alpha=ALPHA,
    seed=SEED,
    stagnation_patience=STAGNATION_PATIENCE,
    mutation_boost=MUTATION_BOOST,
    immigrant_ratio=IMMIGRANT_RATIO,
    boost_duration=BOOST_DURATION,
    boost_cooldown=BOOST_COOLDOWN,
    verbose=True,     
    verbose_interval=1,
)

t0 = time.time()
best, history = ga.run()
elapsed = time.time() - t0

print(f'\nGA 실행 시간: {elapsed:.2f}초 ({elapsed/60:.2f}분)')
# Out:
# GA:   0%|          | 0/400 [00:00<?, ?gen/s]
# [Gen   0] best_fitness=309.09  makespan=230.56  qtime=314.10  avg=405.63
# [Gen   1] best_fitness=309.09  makespan=230.56  qtime=314.10  avg=393.01
# [Gen   2] best_fitness=306.17  makespan=219.46  qtime=346.84  avg=395.36
# [Gen   3] best_fitness=306.17  makespan=219.46  qtime=346.84  avg=380.69
# [Gen   4] best_fitness=298.37  makespan=222.72  qtime=302.59  avg=387.07
# [Gen   5] best_fitness=298.37  makespan=222.72  qtime=302.59  avg=384.16
# [Gen   6] best_fitness=298.37  makespan=222.72  qtime=302.59  avg=384.64
# [Gen   7] best_fitness=293.27  makespan=233.85  qtime=237.71  avg=386.47
# [Gen   8] best_fitness=293.27  makespan=233.85  qtime=237.71  avg=383.22
# [Gen   9] best_fitness=293.27  makespan=233.85  qtime=237.71  avg=381.18
# [Gen  10] best_fitness=293.27  makespan=233.85  qtime=237.71  avg=380.01
# [Gen  11] best_fitness=293.27  makespan=233.85  qtime=237.71  avg=376.12
# [Gen  12] best_fitness=291.54  makespan=220.82  qtime=282.89  avg=365.84
# [Gen  13] best_fitness=291.54  makespan=220.82  qtime=282.89  avg=367.45
# [Gen  14] best_fitness=291.54  makespan=220.82  qtime=282.89  avg=364.06
# [Gen  15] best_fitness=285.22  makespan=220.09  qtime=260.55  avg=363.52
# [Gen  16] best_fitness=285.22  makespan=220.09  qtime=260.55  avg=356.31
# [Gen  17] best_fitness=285.22  makespan=220.09  qtime=260.55  avg=359.45
# [Gen  18] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=355.54
# [Gen  19] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=351.99
# [Gen  20] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=350.74
# [Gen  21] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=353.01
# [Gen  22] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=344.95
# [Gen  23] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=343.42
# [Gen  24] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=341.06
# [Gen  25] best_fitness=269.92  makespan=225.29  qtime=178.52  avg=336.44
# [Gen  26] best_fitness=261.86  makespan=233.88  qtime=111.92  avg=337.66
# [Gen  27] best_fitness=261.86  makespan=233.88  qtime=111.92  avg=335.30
# [Gen  28] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=329.42
# [Gen  29] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=328.76
# [Gen  30] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=321.52
# [Gen  31] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=322.91
# [Gen  32] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=328.74
# [Gen  33] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=330.21
# [Gen  34] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=323.14
# [Gen  35] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=326.08
# [Gen  36] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=320.37
# [Gen  37] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=318.76
# [Gen  38] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=317.68
# [Gen  39] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=315.42
# [Gen  40] best_fitness=255.94  makespan=221.68  qtime=137.05  avg=311.96
# [Gen  41] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=317.19
# [Gen  42] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=310.97
# [Gen  43] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=316.52
# [Gen  44] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=313.30
# [Gen  45] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=308.63
# [Gen  46] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=305.22
# [Gen  47] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=303.45
# [Gen  48] best_fitness=255.09  makespan=221.68  qtime=133.66  avg=303.61
# [Gen  49] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=299.15
# [Gen  50] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=301.56
# [Gen  51] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=298.92
# [Gen  52] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=299.34
# [Gen  53] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=296.60
# [Gen  54] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=296.05
# [Gen  55] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=299.96
# [Gen  56] best_fitness=249.93  makespan=208.03  qtime=167.59  avg=299.17
# [Gen  57] best_fitness=247.56  makespan=212.81  qtime=139.01  avg=293.97
# [Gen  58] best_fitness=247.56  makespan=212.81  qtime=139.01  avg=293.70
# [Gen  59] best_fitness=247.56  makespan=212.81  qtime=139.01  avg=294.90
# [Gen  60] best_fitness=245.74  makespan=208.73  qtime=148.04  avg=293.77
# [Gen  61] best_fitness=245.74  makespan=208.73  qtime=148.04  avg=291.93
# [Gen  62] best_fitness=245.64  makespan=215.05  qtime=122.33  avg=293.01
# [Gen  63] best_fitness=245.64  makespan=215.05  qtime=122.33  avg=288.19
# [Gen  64] best_fitness=242.83  makespan=213.50  qtime=117.32  avg=287.72
# [Gen  65] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=284.54
# [Gen  66] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=281.89
# [Gen  67] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=283.67
# [Gen  68] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=279.39
# [Gen  69] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=282.07
# [Gen  70] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=282.14
# [Gen  71] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=276.71
# [Gen  72] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=275.31
# [Gen  73] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=275.00
# [Gen  74] best_fitness=230.72  makespan=206.53  qtime=96.76  avg=273.43
# [Gen  75] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=273.51
# [Gen  76] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=267.70
# [Gen  77] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=266.15
# [Gen  78] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=267.43
# [Gen  79] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=260.85
# [Gen  80] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=260.63
# [Gen  81] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=257.38
# [Gen  82] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=258.26
# [Gen  83] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=257.08
# [Gen  84] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=256.43
# [Gen  85] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=254.06
# [Gen  86] best_fitness=223.98  makespan=210.08  qtime=55.58  avg=255.17
# [Gen  87] best_fitness=220.76  makespan=211.55  qtime=36.83  avg=255.98
# [Gen  88] best_fitness=220.76  makespan=211.55  qtime=36.83  avg=253.25
# [Gen  89] best_fitness=220.76  makespan=211.55  qtime=36.83  avg=254.92
# [Gen  90] best_fitness=220.76  makespan=211.55  qtime=36.83  avg=255.20
# [Gen  91] best_fitness=220.76  makespan=211.55  qtime=36.83  avg=255.63
# [Gen  92] best_fitness=220.76  makespan=211.55  qtime=36.83  avg=256.26
# [Gen  93] best_fitness=220.71  makespan=211.37  qtime=37.36  avg=254.43
# [Gen  94] best_fitness=220.71  makespan=211.37  qtime=37.36  avg=255.65
# [Gen  95] best_fitness=220.71  makespan=211.37  qtime=37.36  avg=256.87
# [Gen  96] best_fitness=220.71  makespan=211.37  qtime=37.36  avg=258.99
# [Gen  97] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=254.89
# [Gen  98] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=253.15
# [Gen  99] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=256.26
# [Gen 100] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=254.69
# [Gen 101] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=253.63
# [Gen 102] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=257.58
# [Gen 103] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=255.61
# [Gen 104] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=254.49
# [Gen 105] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=258.30
# [Gen 106] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=258.49
# [Gen 107] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=256.51
# [Gen 108] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=256.46
# [Gen 109] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=257.87
# [Gen 110] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=255.75
# [Gen 111] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=254.89
# [Gen 112] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=253.91
# [Gen 113] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=254.22
# [Gen 114] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=250.93
# [Gen 115] best_fitness=220.68  makespan=211.34  qtime=37.36  avg=246.48
# [Gen 116] best_fitness=220.58  makespan=211.24  qtime=37.36  avg=248.73
# [Gen 117] best_fitness=220.58  makespan=211.24  qtime=37.36  avg=250.66
# [Gen 118] best_fitness=219.95  makespan=210.48  qtime=37.87  avg=249.59
# [Gen 119] best_fitness=219.95  makespan=210.48  qtime=37.87  avg=248.38
# [Gen 120] best_fitness=219.40  makespan=208.16  qtime=44.97  avg=249.17
# [Gen 121] best_fitness=216.81  makespan=208.29  qtime=34.06  avg=250.64
# [Gen 122] best_fitness=216.81  makespan=208.29  qtime=34.06  avg=250.40
# [Gen 123] best_fitness=216.81  makespan=208.29  qtime=34.06  avg=248.96
# [Gen 124] best_fitness=216.81  makespan=208.29  qtime=34.06  avg=248.49
# [Gen 125] best_fitness=214.37  makespan=204.99  qtime=37.53  avg=246.75
# [Gen 126] best_fitness=214.37  makespan=204.99  qtime=37.53  avg=245.44
# [Gen 127] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=246.80
# [Gen 128] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=245.11
# [Gen 129] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=244.09
# [Gen 130] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=242.37
# [Gen 131] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=242.88
# [Gen 132] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=239.18
# [Gen 133] best_fitness=213.73  makespan=206.51  qtime=28.90  avg=236.31
# [Gen 134] best_fitness=213.49  makespan=206.20  qtime=29.16  avg=239.33
# [Gen 135] best_fitness=213.25  makespan=202.27  qtime=43.93  avg=235.54
# [Gen 136] best_fitness=213.25  makespan=202.27  qtime=43.93  avg=240.57
# [Gen 137] best_fitness=212.88  makespan=201.89  qtime=43.93  avg=236.17
# [Gen 138] best_fitness=212.88  makespan=201.89  qtime=43.93  avg=235.12
# [Gen 139] best_fitness=212.88  makespan=201.89  qtime=43.93  avg=236.80
# [Gen 140] best_fitness=212.88  makespan=201.89  qtime=43.93  avg=240.10
# [Gen 141] best_fitness=212.88  makespan=201.89  qtime=43.93  avg=242.27
# [Gen 142] best_fitness=212.88  makespan=201.89  qtime=43.93  avg=242.23
# [Gen 143] best_fitness=212.00  makespan=204.38  qtime=30.50  avg=241.32
# [Gen 144] best_fitness=212.00  makespan=204.38  qtime=30.50  avg=244.58
# [Gen 145] best_fitness=212.00  makespan=204.38  qtime=30.50  avg=241.80
# [Gen 146] best_fitness=210.82  makespan=203.47  qtime=29.42  avg=239.41
# [Gen 147] best_fitness=210.82  makespan=203.47  qtime=29.42  avg=239.46
# [Gen 148] best_fitness=210.82  makespan=203.47  qtime=29.42  avg=235.46
# [Gen 149] best_fitness=210.22  makespan=202.28  qtime=31.76  avg=236.30
# [Gen 150] best_fitness=210.22  makespan=202.28  qtime=31.76  avg=237.38
# [Gen 151] best_fitness=210.22  makespan=202.28  qtime=31.76  avg=236.01
# [Gen 152] best_fitness=210.22  makespan=202.28  qtime=31.76  avg=237.60
# [Gen 153] best_fitness=208.51  makespan=200.61  qtime=31.60  avg=233.85
# [Gen 154] best_fitness=208.51  makespan=200.61  qtime=31.60  avg=234.08
# [Gen 155] best_fitness=207.61  makespan=199.71  qtime=31.60  avg=236.10
# [Gen 156] best_fitness=207.61  makespan=199.71  qtime=31.60  avg=231.31
# [Gen 157] best_fitness=207.61  makespan=199.71  qtime=31.60  avg=232.49
# [Gen 158] best_fitness=207.61  makespan=199.71  qtime=31.60  avg=233.85
# [Gen 159] best_fitness=207.61  makespan=199.71  qtime=31.60  avg=231.60
# [Gen 160] best_fitness=207.17  makespan=203.44  qtime=14.93  avg=233.39
# [Gen 161] best_fitness=207.17  makespan=203.44  qtime=14.93  avg=230.58
# [Gen 162] best_fitness=207.17  makespan=203.44  qtime=14.93  avg=233.58
# [Gen 163] best_fitness=206.53  makespan=201.08  qtime=21.80  avg=230.76
# [Gen 164] best_fitness=206.34  makespan=199.96  qtime=25.53  avg=233.40
# [Gen 165] best_fitness=206.34  makespan=199.96  qtime=25.53  avg=234.00
# [Gen 166] best_fitness=206.34  makespan=199.96  qtime=25.53  avg=234.18
# [Gen 167] best_fitness=205.14  makespan=199.96  qtime=20.75  avg=231.58
# [Gen 168] best_fitness=205.14  makespan=199.96  qtime=20.75  avg=231.10
# [Gen 169] best_fitness=205.14  makespan=199.96  qtime=20.75  avg=232.99
# [Gen 170] best_fitness=205.14  makespan=199.96  qtime=20.75  avg=231.51
# [Gen 171] best_fitness=205.14  makespan=199.96  qtime=20.75  avg=228.78
# [Gen 172] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=230.68
# [Gen 173] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=227.30
# [Gen 174] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=227.06
# [Gen 175] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=231.53
# [Gen 176] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=227.72
# [Gen 177] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=231.68
# [Gen 178] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=232.43
# [Gen 179] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=231.56
# [Gen 180] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=232.96
# [Gen 181] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=231.10
# [Gen 182] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=229.84
# [Gen 183] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=226.21
# [Gen 184] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=233.20
# [Gen 185] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=227.56
# [Gen 186] best_fitness=204.46  makespan=199.91  qtime=18.20  avg=227.30
# [Gen 187] best_fitness=204.06  makespan=200.04  qtime=16.06  avg=227.46
# [Gen 188] best_fitness=204.06  makespan=200.04  qtime=16.06  avg=226.67
# [Gen 189] best_fitness=204.06  makespan=200.04  qtime=16.06  avg=228.76
# [Gen 190] best_fitness=204.06  makespan=200.04  qtime=16.06  avg=228.51
# [Gen 191] best_fitness=203.97  makespan=199.96  qtime=16.06  avg=228.41
# [Gen 192] best_fitness=203.54  makespan=197.47  qtime=24.25  avg=229.91
# [Gen 193] best_fitness=203.54  makespan=197.47  qtime=24.25  avg=229.24
# [Gen 194] best_fitness=203.54  makespan=197.47  qtime=24.25  avg=230.79
# [Gen 195] best_fitness=203.54  makespan=197.47  qtime=24.25  avg=232.56
# [Gen 196] best_fitness=203.54  makespan=197.47  qtime=24.25  avg=231.89
# [Gen 197] best_fitness=203.48  makespan=197.47  qtime=24.01  avg=230.20
# [Gen 198] best_fitness=203.48  makespan=197.47  qtime=24.01  avg=232.35
# [Gen 199] best_fitness=202.78  makespan=198.84  qtime=15.76  avg=231.02
# [Gen 200] best_fitness=202.78  makespan=198.84  qtime=15.76  avg=225.62
# [Gen 201] best_fitness=202.78  makespan=198.84  qtime=15.76  avg=230.78
# [Gen 202] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=230.51
# [Gen 203] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=228.48
# [Gen 204] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=227.63
# [Gen 205] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=225.32
# [Gen 206] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=228.31
# [Gen 207] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=228.81
# [Gen 208] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=226.49
# [Gen 209] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=226.85
# [Gen 210] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=225.08
# [Gen 211] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=227.98
# [Gen 212] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=226.24
# [Gen 213] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=228.30
# [Gen 214] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=226.87
# [Gen 215] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=225.61
# [Gen 216] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=227.42
# [Gen 217] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=224.53
# [Gen 218] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=227.73
# [Gen 219] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=224.64
# [Gen 220] best_fitness=201.58  makespan=197.64  qtime=15.73  avg=228.28
# [Gen 221] best_fitness=201.36  makespan=198.37  qtime=11.96  avg=227.58
# [Gen 222] best_fitness=201.13  makespan=197.20  qtime=15.73  avg=224.57
# [Gen 223] best_fitness=201.13  makespan=197.20  qtime=15.73  avg=223.88
# [Gen 224] best_fitness=201.13  makespan=197.20  qtime=15.73  avg=227.38
# [Gen 225] best_fitness=201.13  makespan=197.20  qtime=15.73  avg=226.42
# [Gen 226] best_fitness=201.13  makespan=197.20  qtime=15.73  avg=228.92
# [Gen 227] best_fitness=201.13  makespan=197.20  qtime=15.73  avg=225.92
# [Gen 228] best_fitness=200.65  makespan=197.48  qtime=12.69  avg=227.25
# [Gen 229] best_fitness=200.65  makespan=197.48  qtime=12.69  avg=224.76
# [Gen 230] best_fitness=200.65  makespan=197.48  qtime=12.69  avg=220.77
# [Gen 231] best_fitness=200.36  makespan=197.31  qtime=12.21  avg=225.06
# [Gen 232] best_fitness=200.36  makespan=197.31  qtime=12.21  avg=225.43
# [Gen 233] best_fitness=199.55  makespan=196.21  qtime=13.38  avg=225.44
# [Gen 234] best_fitness=199.55  makespan=196.21  qtime=13.38  avg=223.37
# [Gen 235] best_fitness=199.55  makespan=196.21  qtime=13.38  avg=224.64
# [Gen 236] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=227.06
# [Gen 237] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=223.80
# [Gen 238] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=229.10
# [Gen 239] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=229.82
# [Gen 240] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=226.87
# [Gen 241] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=224.84
# [Gen 242] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=225.43
# [Gen 243] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=226.28
# [Gen 244] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=225.13
# [Gen 245] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=229.60
# [Gen 246] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=226.76
# [Gen 247] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=226.73
# [Gen 248] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=225.09
# [Gen 249] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=226.63
# [Gen 250] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=225.57
# [Gen 251] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=229.04
# [Gen 252] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=225.00
# [Gen 253] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=224.97
# [Gen 254] best_fitness=198.95  makespan=195.99  qtime=11.82  avg=227.29
# [Gen 255] best_fitness=198.70  makespan=195.96  qtime=10.95  avg=223.48
# [Gen 256] best_fitness=198.70  makespan=195.96  qtime=10.95  avg=223.09
# [Gen 257] best_fitness=198.59  makespan=195.63  qtime=11.82  avg=227.91
# [Gen 258] best_fitness=198.59  makespan=195.63  qtime=11.82  avg=220.61
# [Gen 259] best_fitness=198.59  makespan=195.63  qtime=11.82  avg=219.76
# [Gen 260] best_fitness=198.07  makespan=195.63  qtime=9.75  avg=216.51
# [Gen 261] best_fitness=198.07  makespan=195.63  qtime=9.75  avg=224.78
# [Gen 262] best_fitness=198.07  makespan=195.63  qtime=9.75  avg=222.24
# [Gen 263] best_fitness=198.00  makespan=195.30  qtime=10.82  avg=222.36
# [Gen 264] best_fitness=198.00  makespan=195.30  qtime=10.82  avg=227.18
# [Gen 265] best_fitness=198.00  makespan=195.30  qtime=10.82  avg=223.09
# [Gen 266] best_fitness=198.00  makespan=195.30  qtime=10.82  avg=221.57
# [Gen 267] best_fitness=197.90  makespan=195.39  qtime=10.03  avg=225.04
# [Gen 268] best_fitness=197.90  makespan=195.39  qtime=10.03  avg=220.72
# [Gen 269] best_fitness=197.71  makespan=195.23  qtime=9.90  avg=226.12
# [Gen 270] best_fitness=197.71  makespan=195.23  qtime=9.90  avg=219.61
# [Gen 271] best_fitness=197.71  makespan=195.23  qtime=9.90  avg=219.56
# [Gen 272] best_fitness=197.64  makespan=195.17  qtime=9.90  avg=223.07
# [Gen 273] best_fitness=197.64  makespan=195.17  qtime=9.90  avg=222.84
# [Gen 274] best_fitness=197.64  makespan=195.17  qtime=9.90  avg=222.16
# [Gen 275] best_fitness=197.64  makespan=195.17  qtime=9.90  avg=220.33
# [Gen 276] best_fitness=197.64  makespan=195.17  qtime=9.90  avg=222.94
# [Gen 277] best_fitness=197.64  makespan=195.19  qtime=9.77  avg=222.63
# [Gen 278] best_fitness=197.64  makespan=195.19  qtime=9.77  avg=219.48
# [Gen 279] best_fitness=197.64  makespan=195.19  qtime=9.77  avg=219.30
# [Gen 280] best_fitness=197.64  makespan=195.19  qtime=9.77  avg=223.72
# [Gen 281] best_fitness=197.64  makespan=195.19  qtime=9.77  avg=225.33
# [Gen 282] best_fitness=197.55  makespan=195.12  qtime=9.75  avg=223.44
# [Gen 283] best_fitness=197.55  makespan=195.12  qtime=9.75  avg=218.49
# [Gen 284] best_fitness=197.55  makespan=195.12  qtime=9.75  avg=221.86
# [Gen 285] best_fitness=197.55  makespan=195.12  qtime=9.75  avg=219.61
# [Gen 286] best_fitness=197.55  makespan=195.12  qtime=9.75  avg=221.65
# [Gen 287] best_fitness=197.39  makespan=194.92  qtime=9.90  avg=220.92
# [Gen 288] best_fitness=197.39  makespan=194.92  qtime=9.90  avg=220.97
# [Gen 289] best_fitness=197.39  makespan=194.92  qtime=9.90  avg=223.60
# [Gen 290] best_fitness=197.39  makespan=194.92  qtime=9.90  avg=219.02
# [Gen 291] best_fitness=197.30  makespan=194.92  qtime=9.55  avg=221.02
# [Gen 292] best_fitness=197.30  makespan=194.92  qtime=9.55  avg=227.36
# [Gen 293] best_fitness=197.30  makespan=194.92  qtime=9.55  avg=221.32
# [Gen 294] best_fitness=197.01  makespan=195.12  qtime=7.58  avg=220.31
# [Gen 295] best_fitness=196.89  makespan=195.12  qtime=7.09  avg=221.98
# [Gen 296] best_fitness=196.89  makespan=195.12  qtime=7.09  avg=223.64
# [Gen 297] best_fitness=196.89  makespan=195.12  qtime=7.09  avg=222.93
# [Gen 298] best_fitness=196.89  makespan=195.12  qtime=7.09  avg=225.54
# [Gen 299] best_fitness=196.89  makespan=195.12  qtime=7.09  avg=223.60
# [Gen 300] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=224.05
# [Gen 301] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=222.36
# [Gen 302] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=225.31
# [Gen 303] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=224.37
# [Gen 304] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=220.13
# [Gen 305] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=222.22
# [Gen 306] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=219.11
# [Gen 307] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=222.35
# [Gen 308] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=221.87
# [Gen 309] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=221.10
# [Gen 310] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=223.46
# [Gen 311] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=222.52
# [Gen 312] best_fitness=196.69  makespan=194.92  qtime=7.09  avg=223.21
# [Gen 313] best_fitness=196.53  makespan=194.76  qtime=7.09  avg=224.98
# [Gen 314] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=222.80
# [Gen 315] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=224.52
# [Gen 316] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=221.31
# [Gen 317] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.46
# [Gen 318] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=222.86
# [Gen 319] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=220.50
# [Gen 320] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=223.35
# [Gen 321] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.86
# [Gen 322] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=217.56
# [Gen 323] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=221.21
# [Gen 324] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=223.51
# [Gen 325] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=216.92
# [Gen 326] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=220.12
# [Gen 327] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.59
# [Gen 328] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=221.52
# [Gen 329] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=218.43
# [Gen 330] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=216.82
# [Gen 331] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=221.18
# [Gen 332] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=216.59
# [Gen 333] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.04
# [Gen 334] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=226.63
# [Gen 335] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=222.82
# [Gen 336] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.48
# [Gen 337] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=215.41
# [Gen 338] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=220.86
# [Gen 339] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=217.28
# [Gen 340] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.92
# [Gen 341] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=219.66
# [Gen 342] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=222.30
# [Gen 343] best_fitness=196.44  makespan=194.67  qtime=7.09  avg=223.80
# [Gen 344] best_fitness=196.31  makespan=194.54  qtime=7.09  avg=223.01
# [Gen 345] best_fitness=196.31  makespan=194.54  qtime=7.09  avg=224.55
# [Gen 346] best_fitness=196.31  makespan=194.54  qtime=7.09  avg=222.09
# [Gen 347] best_fitness=196.24  makespan=194.47  qtime=7.09  avg=223.73
# [Gen 348] best_fitness=196.24  makespan=194.47  qtime=7.09  avg=220.56
# [Gen 349] best_fitness=196.24  makespan=194.47  qtime=7.09  avg=223.03
# [Gen 350] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.71
# [Gen 351] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.62
# [Gen 352] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=217.37
# [Gen 353] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.30
# [Gen 354] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.03
# [Gen 355] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.68
# [Gen 356] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.26
# [Gen 357] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.32
# [Gen 358] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=217.57
# [Gen 359] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.68
# [Gen 360] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.36
# [Gen 361] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.22
# [Gen 362] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=217.97
# [Gen 363] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=216.91
# [Gen 364] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=217.89
# [Gen 365] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.59
# [Gen 366] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.40
# [Gen 367] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=221.13
# [Gen 368] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.19
# [Gen 369] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.81
# [Gen 370] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.27
# [Gen 371] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=225.24
# [Gen 372] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=225.58
# [Gen 373] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=226.46
# [Gen 374] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=227.33
# [Gen 375] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=223.56
# [Gen 376] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=223.82
# [Gen 377] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.46
# [Gen 378] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=216.79
# [Gen 379] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.32
# [Gen 380] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=216.90
# [Gen 381] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.17
# [Gen 382] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=225.93
# [Gen 383] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=225.41
# [Gen 384] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=221.59
# [Gen 385] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.13
# [Gen 386] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=221.83
# [Gen 387] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.34
# [Gen 388] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.33
# [Gen 389] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=218.11
# [Gen 390] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=221.14
# [Gen 391] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=219.91
# [Gen 392] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=221.00
# [Gen 393] best_fitness=196.21  makespan=194.43  qtime=7.09  avg=220.68
# [Gen 394] best_fitness=196.15  makespan=194.38  qtime=7.09  avg=216.52
# [Gen 395] best_fitness=196.15  makespan=194.38  qtime=7.09  avg=222.46
# [Gen 396] best_fitness=196.15  makespan=194.38  qtime=7.09  avg=220.79
# [Gen 397] best_fitness=196.15  makespan=194.38  qtime=7.09  avg=223.28
# [Gen 398] best_fitness=196.15  makespan=194.38  qtime=7.09  avg=224.22
# [Gen 399] best_fitness=196.15  makespan=194.38  qtime=7.09  avg=222.87
# [Gen 400] best_fitness=196.14  makespan=194.38  qtime=7.05  avg=222.62
#
# GA 실행 시간: 3985.34초 (66.42분)

# %% [markdown]
# ## 수렴 곡선
#
# 세대별 best/avg fitness 추이 + best의 두 지표(makespan, qtime) 변화.

# %%
df_history = pd.DataFrame(history)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# (1) Fitness 수렴 곡선
axes[0].plot(df_history['gen'], df_history['best_fitness'], label='best', color='C0', linewidth=2)
axes[0].plot(df_history['gen'], df_history['avg_fitness'], label='avg', color='C1', alpha=0.6)
axes[0].set_xlabel('Generation')
axes[0].set_ylabel('Fitness (lower is better)')
axes[0].set_title('GA 수렴 곡선')
axes[0].legend()
axes[0].grid(alpha=0.3)

# (2) Best chromosome 두 지표 변화
ax2 = axes[1]
l1 = ax2.plot(df_history['gen'], df_history['best_makespan'], label='makespan', color='C2')
ax2.set_xlabel('Generation')
ax2.set_ylabel('makespan', color='C2')
ax2.tick_params(axis='y', labelcolor='C2')

ax2_t = ax2.twinx()
l2 = ax2_t.plot(df_history['gen'], df_history['best_qtime'], label='qtime', color='C3')
ax2_t.set_ylabel('qtime_violation', color='C3')
ax2_t.tick_params(axis='y', labelcolor='C3')

ax2.set_title('best chromosome 두 지표 변화')
ax2.grid(alpha=0.3)

lines = l1 + l2
ax2.legend(lines, [l.get_label() for l in lines], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 최종 best chromosome 정보

# %%
sim_input_best = decode(best, encoded)

print('─── best chromosome fitness ───')
print(f'  makespan: {best.fitness[0]:.2f}')
print(f'  qtime:    {best.fitness[1]:.2f}')
print()
print('─── 디코딩 결과 (시뮬 실제 입력) ───')
print(f'  job 투입 순서: {sim_input_best.job_priority}')
print()
print(f'  pm_thresholds: {sim_input_best.pm_thresholds}')
print()
print('  op별 머신 할당 (앞 10개):')
for op, m in list(sim_input_best.op_machine.items())[:10]:
    print(f'    {op} → {m}')
# Out:
# ─── best chromosome fitness ───
#   makespan: 194.38
#   qtime:    7.05
#
# ─── 디코딩 결과 (시뮬 실제 입력) ───
#   job 투입 순서: ['J44', 'J57', 'J56', 'J10', 'J34', 'J30', 'J1', 'J20', 'J43', 'J4', 'J21', 'J46', 'J18', 'J25', 'J42', 'J47', 'J26', 'J16', 'J33', 'J12', 'J13', 'J3', 'J23', 'J6', 'J27', 'J49', 'J45', 'J37', 'J52', 'J28', 'J60', 'J8', 'J50', 'J15', 'J32', 'J58', 'J2', 'J40', 'J9', 'J55', 'J39', 'J14', 'J5', 'J7', 'J24', 'J35', 'J53', 'J22', 'J38', 'J41', 'J11', 'J48', 'J19', 'J59', 'J29', 'J54', 'J31', 'J36', 'J17', 'J51']
#
#   pm_thresholds: {'M1': 0.07, 'M2': 0.05, 'M3': 0.05, 'M4': 0.07, 'M5': 0.01, 'M6': 0.09, 'M7': 0.03, 'M8': 0.07, 'M9': 0.1, 'M10': 0.1, 'M11': 0.2, 'M12': 0.07, 'M13': 0.09, 'M14': 0.01, 'M15': 0.01, 'M16': 0.03, 'M17': 0.03, 'M18': 0.2, 'M19': 0.01, 'M20': 0.03, 'M21': 0.05, 'M22': 0.09, 'M23': 0.07, 'M24': 0.2, 'M25': 0.01, 'M26': 0.05, 'M27': 0.05, 'M28': 0.07, 'M29': 0.07, 'M30': 0.05, 'M31': 0.01, 'M32': 0.01, 'M33': 0.09, 'M34': 0.03, 'M35': 0.01, 'M36': 0.07, 'M37': 0.07, 'M38': 0.09, 'M39': 0.1, 'M40': 0.03, 'M41': 0.03, 'M42': 0.01, 'M43': 0.05, 'M44': 0.03, 'M45': 0.03, 'M46': 0.2, 'M47': 0.05, 'M48': 0.09, 'M49': 0.07, 'M50': 0.1, 'M51': 0.1, 'M52': 0.2, 'M53': 0.09, 'M54': 0.2, 'M55': 0.09, 'M56': 0.09, 'M57': 0.1, 'M58': 0.2, 'M59': 0.03, 'M60': 0.05}
#
#   op별 머신 할당 (앞 10개):
#     J1_O1 → M43
#     J1_O2 → M26
#     J1_O3 → M40
#     J1_O4 → M16
#     J1_O5 → M58
#     J1_O6 → M13
#     J1_O7 → M49
#     J1_O8 → M5
#     J1_O9 → M55
#     J1_O10 → M25

# %% [markdown]
# ## Best chromosome 시뮬레이션 + 간트 차트
#
# GA가 찾아낸 best chromosome으로 시뮬레이션을 한 번 더 돌려 간트 차트 시각화.

# %%
# best chromosome으로 시뮬레이션 재실행 (시드 고정 → fitness와 동일 결과)
random.seed(ga.evaluator.seed)

env = simpy.Environment()
event_logger = EventLogger(env)
scheduler = Scheduler(
    env=env,
    data=data,
    event_logger=event_logger,
    pm_hazard_threshold=0.0,
    job_priority=sim_input_best.job_priority,
    op_machine=sim_input_best.op_machine,
    pm_thresholds=sim_input_best.pm_thresholds,
)
env.run(until=scheduler.job_chk_process)

fig = create_gantt_chart(
    logs=event_logger.logs,
    max_time=env.now,
    title=f'GA Best Chromosome 간트 차트 (Simulation Time: {round(env.now / 60, 3)} h)'
)
fig.show()

# %% [markdown]
# ## 초기 vs 최종 비교

# %%
init = history[0]
final = history[-1]

print('─── 초기 (gen 0, 무작위) ───')
print(f"  best fitness: {init['best_fitness']:.2f}")
print(f"    makespan:   {init['best_makespan']:.2f}")
print(f"    qtime:      {init['best_qtime']:.2f}")
print(f"  avg  fitness: {init['avg_fitness']:.2f}")
print()
print('─── 최종 (GA 진화 후) ───')
print(f"  best fitness: {final['best_fitness']:.2f}")
print(f"    makespan:   {final['best_makespan']:.2f}")
print(f"    qtime:      {final['best_qtime']:.2f}")
print(f"  avg  fitness: {final['avg_fitness']:.2f}")
print()

def pct_change(initial, final_val):
    """초기값이 0이면 절대 변화량 표시, 아니면 변화율(%) 표시."""
    if initial == 0:
        return f'{initial:.2f} → {final_val:.2f} (초기값 0이라 변화율 미정의)'
    return f'{(final_val - initial) / initial * 100:+.1f}%'

print(f'best fitness 개선율: {pct_change(init["best_fitness"], final["best_fitness"])}')
print(f'makespan 변화율:     {pct_change(init["best_makespan"], final["best_makespan"])}')
print(f'qtime 변화율:        {pct_change(init["best_qtime"], final["best_qtime"])}')
# Out:
# ─── 초기 (gen 0, 무작위) ───
#   best fitness: 309.09
#     makespan:   230.56
#     qtime:      314.10
#   avg  fitness: 405.63
#
# ─── 최종 (GA 진화 후) ───
#   best fitness: 196.14
#     makespan:   194.38
#     qtime:      7.05
#   avg  fitness: 222.62
#
# best fitness 개선율: -36.5%
# makespan 변화율:     -15.7%
# qtime 변화율:        -97.8%

# %% [markdown]
# ## 결과 저장
#
# 세대별 history는 CSV로, best chromosome 간트 차트는 HTML로 같은 폴더에 저장. 번호는 자동 증가.

# %%
SAVE_DIR = 'ga결과/'   # 결과 저장 폴더
os.makedirs(SAVE_DIR, exist_ok=True)


def next_filepath(prefix: str, suffix: str) -> str:
    """SAVE_DIR 안에서 {prefix}NNN{suffix} 패턴의 가장 큰 번호 + 1로 새 경로 반환."""
    existing_nums = [
        int(f[len(prefix):-len(suffix)])
        for f in os.listdir(SAVE_DIR)
        if f.startswith(prefix) and f.endswith(suffix)
        and f[len(prefix):-len(suffix)].isdigit()
    ]
    next_num = max(existing_nums, default=0) + 1
    return os.path.join(SAVE_DIR, f'{prefix}{next_num:03d}{suffix}')


# ─── CSV 저장 (세대별 history + GA 파라미터는 첫 행에만) ───
params = {
    'pm_levels':           str(PM_LEVELS),
    'pop_size':            POP_SIZE,
    'n_generations':       N_GENERATIONS,
    'crossover_rate':      CROSSOVER_RATE,
    'mut_job':             MUT_JOB,
    'mut_machine':         MUT_MACHINE,
    'mut_pm':              MUT_PM,
    'tournament_k':        TOURNAMENT_K,
    'n_elites':            N_ELITES,
    'alpha':               ALPHA,
    'stagnation_patience': STAGNATION_PATIENCE,
    'mutation_boost':      MUTATION_BOOST,
    'immigrant_ratio':     IMMIGRANT_RATIO,
    'boost_duration':      BOOST_DURATION,
    'boost_cooldown':      BOOST_COOLDOWN,
    'seed':                SEED,
}
df_out = df_history.copy()
for k, v in params.items():
    df_out[k] = ''
    df_out.at[0, k] = v

csv_path = next_filepath('result_ga_history_', '.csv')
df_out.to_csv(csv_path, index=False, encoding='utf-8-sig')
print(f'saved: {csv_path}')

# ─── HTML 저장 (best 간트 차트) ───
html_path = next_filepath('result_ga_gantt_', '.html')
fig.write_html(html_path)
print(f'saved: {html_path}')
# Out:
# saved: ga결과/result_ga_history_017.csv
# saved: ga결과/result_ga_gantt_017.html
